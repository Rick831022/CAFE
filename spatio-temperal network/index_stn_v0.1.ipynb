# %% [markdown]
# ## Index<a id='top'></a>
# ### [two stream 论文](#a2)
# ### [光流论文](#a1)
# ---

# %% [markdown]
# ### 光流论文解读<a id='a1'></a>
# ---
# #### Optical Flow 基础
# [optical flow wiki](https://en.wikipedia.org/wiki/Optical_flow)
# [LK wiki](https://en.wikipedia.org/wiki/Lucas%E2%80%93Kanade_method)
# [OpenCV optical flow](https://docs.opencv.org/3.4/d7/d8b/tutorial_py_lucas_kanade.html)
# [Coarse-to-fine Optical Flow (Lucas & Kanade)](http://eric-yuan.me/coarse-to-fine-optical-flow/)
#
# ---
# #### Optical Flow 解读
# [Optical Flow Introduction](https://allenlu2007.wordpress.com/2016/06/10/optical-flow-and-video-magnification/)
# [Optical Flow – Re-introductio](https://allenlu2007.wordpress.com/2016/07/07/optical-flow-re-introduction/)
# [Optical Flow – Pyramid Lucas & Kanade Method](https://allenlu2007.wordpress.com/2016/06/18/optical-flow-lucas-kanade-method/)
#
# ---
# #### Pyramidal Implementation of the Lucas Kanade Feature Tracker Description of the algorithm - Intel
# [原文](Pyramidal Implementation of the Lucas Kanade Feature Tracker Description of the algorithm _Intel.pdf)
#
#
# ---
# #### 6D-Vision
# [web](http://www.6d-vision.com/)
# [paper](Dense, Robust, and Accurate Motion Field Estimation from Stereo Image Sequences in Real-time _eccv2010.pdf)
# [related dissertation](detection of moving objects by spatio-tempral motion analysis _2011.pdf)
#
# ---
# #### FlowNet Learning Optical Flow with Convolutional Networks
# [原文](FlowNet Learning Optical Flow with Convolutional Networks _May2015.pdf)
# [解读](https://blog.csdn.net/zhangjunhit/article/details/76262429)
#
# ---
# #### LiteFlowNet A Lightweight Convolutional Neural Network for Optical Flow Estimation
# [原文](LiteFlowNet A Lightweight Convolutional Neural Network for Optical Flow Estimation _May2018.pdf)
#
# ---
#
# [返回目录](#top)
#
# ---

# %%
% matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.plot(np.r_[1:10])
